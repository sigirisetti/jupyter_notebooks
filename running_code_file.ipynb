# %%
pwd
# Out:
# '/home/appuprakhya/work/jupyter_notebooks'

# %%
ls
# Out:
# fe/  python_examples/  README.md  running_code_file.ipynb  widgets/

# %%
run ../python/python_projects/pylearn/plotting/Pyplot/color_line.py
