# %% [markdown]
# # Pricers
#
# * Pricer\CC
# * Pricer\CC\BASISSWAP
# * Pricer\CC\BERMUDANPRDCSWAP
# * Pricer\CC\FEE
# * Pricer\CC\FIXEDFLOAT
# * Pricer\CC\KERNEL
# * Pricer\CC\PRDCTARNSWAP
# * Pricer\CC\RESETTABLEBASISSWAP
# * Pricer\CMDTY
# * Pricer\CMDTY\AMERICAN
# * Pricer\CMDTY\ASIAN
# * Pricer\CMDTY\BULLETOPTION
# * Pricer\CMDTY\CALENDARSPREAD
# * Pricer\CMDTY\CALENDARSWAP
# * Pricer\CMDTY\CRACKSPREAD
# * Pricer\CMDTY\EUROPEAN
# * Pricer\CMDTY\FORWARD
# * Pricer\CMDTY\FUTURES
# * Pricer\CMDTY\SWAPTION
# * Pricer\CR
# * Pricer\CR\ASSETSWAP
# * Pricer\CR\CDS
# * Pricer\CR\CDSINDEX
# * Pricer\CR\STATICCDO
# * Pricer\EQ
# * Pricer\EQ\AMERICAN
# * Pricer\EQ\ASIAN
# * Pricer\EQ\AUTOCALLABLE
# * Pricer\EQ\CALLPUTSPREAD
# * Pricer\EQ\CLIQUET
# * Pricer\EQ\COMPOUNDAMERICAN
# * Pricer\EQ\COMPOUNDEUROPEAN
# * Pricer\EQ\CONVERTIBLEBOND
# * Pricer\EQ\DIGITAL
# * Pricer\EQ\DIVIDENDFUTURES
# * Pricer\EQ\DIVIDENDSWAP
# * Pricer\EQ\ELNKIKO
# * Pricer\EQ\EQASIANDUALOPTION
# * Pricer\EQ\EQPOSITION
# * Pricer\EQ\EUROPEAN
# * Pricer\EQ\FUTURES
# * Pricer\EQ\FWDSTARTEUROPEANOPTION
# * Pricer\EQ\INSTALLMENTOPTION
# * Pricer\EQ\INSTRUMENT* Pricer
# * Pricer\EQ\KERNEL
# * Pricer\EQ\LOOKBACK
# * Pricer\EQ\LOOKBACKRANGE
# * Pricer\EQ\RANGEACCRUAL
# * Pricer\EQ\TIMER
# * Pricer\EQ\TOTALRETURNSWAP
# * Pricer\EQ\VARIANCESWAP
# * Pricer\EQ\VIXFUTURES
# * Pricer\EQ\VIXOPTION
# * Pricer\EQ\VOLATILITYSWAP
# * Pricer\FX
# * Pricer\FX\ACCUMULATOR
# * Pricer\FX\AMERICAN
# * Pricer\FX\ASIAN
# * Pricer\FX\BARRIERANALYTIC
# * Pricer\FX\BUTTERFLY
# * Pricer\FX\CHOOSER
# * Pricer\FX\CLIQUET
# * Pricer\FX\COMPOUNDAMERICAN
# * Pricer\FX\COMPOUNDEUROPEAN
# * Pricer\FX\DIGITAL
# * Pricer\FX\DIGITALKIKO
# * Pricer\FX\DKIKO
# * Pricer\FX\DOTNT
# * Pricer\FX\EUROPEAN
# * Pricer\FX\FADER
# * Pricer\FX\FWD* Pricer
# * Pricer\FX\FWDSTARTEUROPEANOPTION
# * Pricer\FX\FXASIANDUALOPTION
# * Pricer\FX\INSTALLMENTOPTION
# * Pricer\FX\KERNEL
# * Pricer\FX\KIKO
# * Pricer\FX\LINKEDNOTE
# * Pricer\FX\LOOKBACK
# * Pricer\FX\LOOKBACKRANGE
# * Pricer\FX\OTNT
# * Pricer\FX\RANGEACCRUAL
# * Pricer\FX\STRATEGIES
# * Pricer\FX\SWAP
# * Pricer\FX\TARF
# * Pricer\FX\VANNAVOLGA
# * Pricer\FX\VARIANCESWAP
# * Pricer\FX\VOLATILITYSWAP
# * Pricer\HY
# * Pricer\HY\EQAMERICANLONGDATED
# * Pricer\HY\EQBASKETPERFORMANCEOPTION
# * Pricer\HY\EQWORSTOFBESTOF
# * Pricer\HY\FXAMERICANLONGDATED
# * Pricer\HY\FXBASKETOPTION
# * Pricer\HY\FXBASKETPERFORMANCEOPTION
# * Pricer\HY\FXDNTQUANTOSWAP
# * Pricer\HY\FXDUALDIGITAL
# * Pricer\HY\FXOUTPERFORMANCE
# * Pricer\HY\FXOUTSPREAD
# * Pricer\HY\KERNEL
# * Pricer\INFL
# * Pricer\INFL\CPICAPFLOOR
# * Pricer\INFL\ILBOND
# * Pricer\INFL\YOYSWAP
# * Pricer\INFL\ZCIIS
# * Pricer\IR
# * Pricer\IR\BERMUDANSWAPTION
# * Pricer\IR\BOND
# * Pricer\IR\BONDFUTURES
# * Pricer\IR\BONDOPTION
# * Pricer\IR\CALLABLEBOND
# * Pricer\IR\CALLABLECMSINVERSEFLOATER
# * Pricer\IR\CALLABLEDUALRABOND
# * Pricer\IR\CALLABLEFRN
# * Pricer\IR\CALLABLERASWAP
# * Pricer\IR\CALLABLERATCHETSWAP
# * Pricer\IR\CALLABLEREVERSEFLOATER
# * Pricer\IR\CALLABLEZEROBOND
# * Pricer\IR\CALLABLEZEROSWAP
# * Pricer\IR\CAPFLOOR
# * Pricer\IR\CAPPEDSWAP
# * Pricer\IR\CASHDEPOSIT
# * Pricer\IR\CMSCAPFLOOR
# * Pricer\IR\CMSSPREADSTEEPENER
# * Pricer\IR\CMSSWAP
# * Pricer\IR\DIGITALCMSCAPFLOOR
# * Pricer\IR\DIGITALLIBORCAPFLOOR
# * Pricer\IR\DISCOUNTSECURITIES
# * Pricer\IR\DMOLOAN
# * Pricer\IR\FLOATINGRATENOTE
# * Pricer\IR\FRA
# * Pricer\IR\GENERICSWAP
# * Pricer\IR\IRSWAP
# * Pricer\IR\KERNEL
# * Pricer\IR\LIBORBASISSWAP
# * Pricer\IR\MANAGEDPOOLRMBS
# * Pricer\IR\RATCHETSWAP
# * Pricer\IR\RATEFUTURES
# * Pricer\IR\REPO
# * Pricer\IR\SBMXNSABOND
# * Pricer\IR\SNOWBALLINVERSEFLOATER
# * Pricer\IR\SNOWBLADEINVERSEFLOATER
# * Pricer\IR\SNOWBLADESWAP
# * Pricer\IR\SWAP
# * Pricer\IR\SWAPTION
